# %% [markdown]
# https://docs.aws.amazon.com/AWSEC2/latest/UserGuide/install-nvidia-driver.html
#
# https://docs.aws.amazon.com/AWSEC2/latest/UserGuide/recognize-expanded-volume-linux.html

# %%
# !sudo yum update -y
# Out:
# Last metadata expiration check: 1 day, 6:00:29 ago on Sat Mar 25 20:57:05 2023.
# ================================================================================
# WARNING:
#   A newer release of "Amazon Linux" is available.
#
#   Available Versions:
#
#   Version 2023.0.20230322:
#     Run the following command to upgrade to 2023.0.20230322:
#
#       dnf upgrade --releasever=2023.0.20230322
#
#     Release notes:
#      https://docs.aws.amazon.com/linux/al2023/release-notes/relnotes.html
#
# ================================================================================
# Dependencies resolved.
# Nothing to do.
# Complete!

# %%
# !pip install numpy
# Out:
# Collecting numpy
#   Using cached numpy-1.24.2-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (17.3 MB)
# Installing collected packages: numpy
# Successfully installed numpy-1.24.2

# %%
# !pip install swifter
# Out:
# Collecting swifter
#   Using cached swifter-1.3.4.tar.gz (830 kB)
#   Preparing metadata (setup.py) ... done
# Collecting pandas>=1.0.0
#   Using cached pandas-1.5.3-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (12.2 MB)
# Requirement already satisfied: psutil>=5.6.6 in ./venv/lib/python3.9/site-packages (from swifter) (5.9.4)
# Collecting dask[dataframe]>=2.10.0
#   Downloading dask-2023.3.2-py3-none-any.whl (1.2 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 20.5 MB/s eta 0:00:00 0:00:01
# Collecting tqdm>=4.33.0
#   Using cached tqdm-4.65.0-py3-none-any.whl (77 kB)
# Collecting ipywidgets>=7.0.0
#   Downloading ipywidgets-8.0.5-py3-none-any.whl (138 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 138.3/138.3 kB 38.0 MB/s eta 0:00:00
# Collecting cloudpickle>=0.2.2
#   Using cached cloudpickle-2.2.1-py3-none-any.whl (25 kB)
# Requirement already satisfied: parso>0.4.0 in ./venv/lib/python3.9/site-packages (from swifter) (0.8.3)
# Requirement already satisfied: bleach>=3.1.1 in ./venv/lib/python3.9/site-packages (from swifter) (6.0.0)
# Requirement already satisfied: webencodings in ./venv/lib/python3.9/site-packages (from bleach>=3.1.1->swifter) (0.5.1)
# Requirement already satisfied: six>=1.9.0 in ./venv/lib/python3.9/site-packages (from bleach>=3.1.1->swifter) (1.16.0)
# Requirement already satisfied: pyyaml>=5.3.1 in ./venv/lib/python3.9/site-packages (from dask[dataframe]>=2.10.0->swifter) (6.0)
# Requirement already satisfied: packaging>=20.0 in ./venv/lib/python3.9/site-packages (from dask[dataframe]>=2.10.0->swifter) (23.0)
# Collecting fsspec>=0.6.0
#   Using cached fsspec-2023.3.0-py3-none-any.whl (145 kB)
# Requirement already satisfied: importlib-metadata>=4.13.0 in ./venv/lib/python3.9/site-packages (from dask[dataframe]>=2.10.0->swifter) (6.1.0)
# Collecting click>=7.0
#   Using cached click-8.1.3-py3-none-any.whl (96 kB)
# Collecting partd>=1.2.0
#   Using cached partd-1.3.0-py3-none-any.whl (18 kB)
# Collecting toolz>=0.8.2
#   Using cached toolz-0.12.0-py3-none-any.whl (55 kB)
# Requirement already satisfied: numpy>=1.21 in ./venv/lib/python3.9/site-packages (from dask[dataframe]>=2.10.0->swifter) (1.24.2)
# Requirement already satisfied: traitlets>=4.3.1 in ./venv/lib/python3.9/site-packages (from ipywidgets>=7.0.0->swifter) (5.9.0)
# Collecting jupyterlab-widgets~=3.0
#   Downloading jupyterlab_widgets-3.0.6-py3-none-any.whl (198 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 198.1/198.1 kB 45.4 MB/s eta 0:00:00
# Collecting widgetsnbextension~=4.0
#   Downloading widgetsnbextension-4.0.6-py3-none-any.whl (2.1 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.1/2.1 MB 99.0 MB/s eta 0:00:00
# Requirement already satisfied: ipython>=6.1.0 in ./venv/lib/python3.9/site-packages (from ipywidgets>=7.0.0->swifter) (8.11.0)
# Collecting pytz>=2020.1
#   Downloading pytz-2023.2-py2.py3-none-any.whl (502 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 502.1/502.1 kB 82.2 MB/s eta 0:00:00
# Requirement already satisfied: python-dateutil>=2.8.1 in ./venv/lib/python3.9/site-packages (from pandas>=1.0.0->swifter) (2.8.2)
# Requirement already satisfied: zipp>=0.5 in ./venv/lib/python3.9/site-packages (from importlib-metadata>=4.13.0->dask[dataframe]>=2.10.0->swifter) (3.15.0)
# Requirement already satisfied: matplotlib-inline in ./venv/lib/python3.9/site-packages (from ipython>=6.1.0->ipywidgets>=7.0.0->swifter) (0.1.6)
# Requirement already satisfied: pygments>=2.4.0 in ./venv/lib/python3.9/site-packages (from ipython>=6.1.0->ipywidgets>=7.0.0->swifter) (2.14.0)
# Requirement already satisfied: decorator in ./venv/lib/python3.9/site-packages (from ipython>=6.1.0->ipywidgets>=7.0.0->swifter) (5.1.1)
# Requirement already satisfied: prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30 in ./venv/lib/python3.9/site-packages (from ipython>=6.1.0->ipywidgets>=7.0.0->swifter) (3.0.38)
# Requirement already satisfied: backcall in ./venv/lib/python3.9/site-packages (from ipython>=6.1.0->ipywidgets>=7.0.0->swifter) (0.2.0)
# Requirement already satisfied: jedi>=0.16 in ./venv/lib/python3.9/site-packages (from ipython>=6.1.0->ipywidgets>=7.0.0->swifter) (0.18.2)
# Requirement already satisfied: pickleshare in ./venv/lib/python3.9/site-packages (from ipython>=6.1.0->ipywidgets>=7.0.0->swifter) (0.7.5)
# Requirement already satisfied: stack-data in ./venv/lib/python3.9/site-packages (from ipython>=6.1.0->ipywidgets>=7.0.0->swifter) (0.6.2)
# Requirement already satisfied: pexpect>4.3 in ./venv/lib/python3.9/site-packages (from ipython>=6.1.0->ipywidgets>=7.0.0->swifter) (4.8.0)
# Collecting locket
#   Using cached locket-1.0.0-py2.py3-none-any.whl (4.4 kB)
# Requirement already satisfied: ptyprocess>=0.5 in ./venv/lib/python3.9/site-packages (from pexpect>4.3->ipython>=6.1.0->ipywidgets>=7.0.0->swifter) (0.7.0)
# Requirement already satisfied: wcwidth in ./venv/lib/python3.9/site-packages (from prompt-toolkit!=3.0.37,<3.1.0,>=3.0.30->ipython>=6.1.0->ipywidgets>=7.0.0->swifter) (0.2.6)
# Requirement already satisfied: asttokens>=2.1.0 in ./venv/lib/python3.9/site-packages (from stack-data->ipython>=6.1.0->ipywidgets>=7.0.0->swifter) (2.2.1)
# Requirement already satisfied: executing>=1.2.0 in ./venv/lib/python3.9/site-packages (from stack-data->ipython>=6.1.0->ipywidgets>=7.0.0->swifter) (1.2.0)
# Requirement already satisfied: pure-eval in ./venv/lib/python3.9/site-packages (from stack-data->ipython>=6.1.0->ipywidgets>=7.0.0->swifter) (0.2.2)
# Installing collected packages: pytz, widgetsnbextension, tqdm, toolz, locket, jupyterlab-widgets, fsspec, cloudpickle, click, partd, pandas, dask, ipywidgets, swifter
#   DEPRECATION: swifter is being installed using the legacy 'setup.py install' method, because it does not have a 'pyproject.toml' and the 'wheel' package is not installed. pip 23.1 will enforce this behaviour change. A possible replacement is to enable the '--use-pep517' option. Discussion can be found at https://github.com/pypa/pip/issues/8559
#   Running setup.py install for swifter ... done
# Successfully installed click-8.1.3 cloudpickle-2.2.1 dask-2023.3.2 fsspec-2023.3.0 ipywidgets-8.0.5 jupyterlab-widgets-3.0.6 locket-1.0.0 pandas-1.5.3 partd-1.3.0 pytz-2023.2 swifter-1.3.4 toolz-0.12.0 tqdm-4.65.0 widgetsnbextension-4.0.6

# %%
# !pip install torch torchvision Pillow matplotlib
# Out:
# Collecting torch
#   Using cached torch-2.0.0-cp39-cp39-manylinux1_x86_64.whl (619.9 MB)
# Collecting torchvision
#   Using cached torchvision-0.15.1-cp39-cp39-manylinux1_x86_64.whl (6.0 MB)
# Collecting Pillow
#   Using cached Pillow-9.4.0-cp39-cp39-manylinux_2_28_x86_64.whl (3.4 MB)
# Collecting matplotlib
#   Using cached matplotlib-3.7.1-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (11.6 MB)
# Collecting nvidia-cudnn-cu11==8.5.0.96
#   Using cached nvidia_cudnn_cu11-8.5.0.96-2-py3-none-manylinux1_x86_64.whl (557.1 MB)
# Collecting nvidia-cublas-cu11==11.10.3.66
#   Using cached nvidia_cublas_cu11-11.10.3.66-py3-none-manylinux1_x86_64.whl (317.1 MB)
# Collecting typing-extensions
#   Using cached typing_extensions-4.5.0-py3-none-any.whl (27 kB)
# Collecting nvidia-cufft-cu11==10.9.0.58
#   Using cached nvidia_cufft_cu11-10.9.0.58-py3-none-manylinux1_x86_64.whl (168.4 MB)
# Collecting nvidia-nccl-cu11==2.14.3
#   Using cached nvidia_nccl_cu11-2.14.3-py3-none-manylinux1_x86_64.whl (177.1 MB)
# Collecting sympy
#   Using cached sympy-1.11.1-py3-none-any.whl (6.5 MB)
# Requirement already satisfied: jinja2 in ./venv/lib/python3.9/site-packages (from torch) (3.1.2)
# Collecting nvidia-nvtx-cu11==11.7.91
#   Using cached nvidia_nvtx_cu11-11.7.91-py3-none-manylinux1_x86_64.whl (98 kB)
# Collecting nvidia-cuda-nvrtc-cu11==11.7.99
#   Using cached nvidia_cuda_nvrtc_cu11-11.7.99-2-py3-none-manylinux1_x86_64.whl (21.0 MB)
# Collecting nvidia-cuda-cupti-cu11==11.7.101
#   Using cached nvidia_cuda_cupti_cu11-11.7.101-py3-none-manylinux1_x86_64.whl (11.8 MB)
# Collecting nvidia-curand-cu11==10.2.10.91
#   Using cached nvidia_curand_cu11-10.2.10.91-py3-none-manylinux1_x86_64.whl (54.6 MB)
# Collecting filelock
#   Using cached filelock-3.10.6-py3-none-any.whl (10 kB)
# Collecting triton==2.0.0
#   Using cached triton-2.0.0-1-cp39-cp39-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (63.3 MB)
# Collecting nvidia-cusparse-cu11==11.7.4.91
#   Using cached nvidia_cusparse_cu11-11.7.4.91-py3-none-manylinux1_x86_64.whl (173.2 MB)
# Collecting nvidia-cusolver-cu11==11.4.0.1
#   Using cached nvidia_cusolver_cu11-11.4.0.1-2-py3-none-manylinux1_x86_64.whl (102.6 MB)
# Collecting networkx
#   Using cached networkx-3.0-py3-none-any.whl (2.0 MB)
# Collecting nvidia-cuda-runtime-cu11==11.7.99
#   Using cached nvidia_cuda_runtime_cu11-11.7.99-py3-none-manylinux1_x86_64.whl (849 kB)
# Collecting wheel
#   Using cached wheel-0.40.0-py3-none-any.whl (64 kB)
# Requirement already satisfied: setuptools in ./venv/lib/python3.9/site-packages (from nvidia-cublas-cu11==11.10.3.66->torch) (59.6.0)
# Collecting lit
#   Using cached lit-16.0.0.tar.gz (144 kB)
#   Preparing metadata (setup.py) ... done
# Collecting cmake
#   Using cached cmake-3.26.1-py2.py3-none-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (24.0 MB)
# Requirement already satisfied: numpy in ./venv/lib/python3.9/site-packages (from torchvision) (1.24.2)
# Requirement already satisfied: requests in ./venv/lib/python3.9/site-packages (from torchvision) (2.28.2)
# Collecting pyparsing>=2.3.1
#   Using cached pyparsing-3.0.9-py3-none-any.whl (98 kB)
# Requirement already satisfied: python-dateutil>=2.7 in ./venv/lib/python3.9/site-packages (from matplotlib) (2.8.2)
# Collecting cycler>=0.10
#   Using cached cycler-0.11.0-py3-none-any.whl (6.4 kB)
# Collecting kiwisolver>=1.0.1
#   Using cached kiwisolver-1.4.4-cp39-cp39-manylinux_2_12_x86_64.manylinux2010_x86_64.whl (1.6 MB)
# Requirement already satisfied: packaging>=20.0 in ./venv/lib/python3.9/site-packages (from matplotlib) (23.0)
# Collecting importlib-resources>=3.2.0
#   Using cached importlib_resources-5.12.0-py3-none-any.whl (36 kB)
# Collecting contourpy>=1.0.1
#   Using cached contourpy-1.0.7-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (299 kB)
# Collecting fonttools>=4.22.0
#   Using cached fonttools-4.39.2-py3-none-any.whl (1.0 MB)
# Requirement already satisfied: zipp>=3.1.0 in ./venv/lib/python3.9/site-packages (from importlib-resources>=3.2.0->matplotlib) (3.15.0)
# Requirement already satisfied: six>=1.5 in ./venv/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib) (1.16.0)
# Requirement already satisfied: MarkupSafe>=2.0 in ./venv/lib/python3.9/site-packages (from jinja2->torch) (2.1.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./venv/lib/python3.9/site-packages (from requests->torchvision) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in ./venv/lib/python3.9/site-packages (from requests->torchvision) (3.4)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in ./venv/lib/python3.9/site-packages (from requests->torchvision) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in ./venv/lib/python3.9/site-packages (from requests->torchvision) (2022.12.7)
# Collecting mpmath>=0.19
#   Using cached mpmath-1.3.0-py3-none-any.whl (536 kB)
# Installing collected packages: mpmath, lit, cmake, wheel, typing-extensions, sympy, pyparsing, Pillow, nvidia-nccl-cu11, nvidia-cufft-cu11, nvidia-cuda-nvrtc-cu11, networkx, kiwisolver, importlib-resources, fonttools, filelock, cycler, contourpy, nvidia-nvtx-cu11, nvidia-cusparse-cu11, nvidia-curand-cu11, nvidia-cuda-runtime-cu11, nvidia-cuda-cupti-cu11, nvidia-cublas-cu11, matplotlib, nvidia-cusolver-cu11, nvidia-cudnn-cu11, triton, torch, torchvision
#   DEPRECATION: lit is being installed using the legacy 'setup.py install' method, because it does not have a 'pyproject.toml' and the 'wheel' package is not installed. pip 23.1 will enforce this behaviour change. A possible replacement is to enable the '--use-pep517' option. Discussion can be found at https://github.com/pypa/pip/issues/8559
#   Running setup.py install for lit ... done
# Successfully installed Pillow-9.4.0 cmake-3.26.1 contourpy-1.0.7 cycler-0.11.0 filelock-3.10.6 fonttools-4.39.2 importlib-resources-5.12.0 kiwisolver-1.4.4 lit-16.0.0 matplotlib-3.7.1 mpmath-1.3.0 networkx-3.0 nvidia-cublas-cu11-11.10.3.66 nvidia-cuda-cupti-cu11-11.7.101 nvidia-cuda-nvrtc-cu11-11.7.99 nvidia-cuda-runtime-cu11-11.7.99 nvidia-cudnn-cu11-8.5.0.96 nvidia-cufft-cu11-10.9.0.58 nvidia-curand-cu11-10.2.10.91 nvidia-cusolver-cu11-11.4.0.1 nvidia-cusparse-cu11-11.7.4.91 nvidia-nccl-cu11-2.14.3 nvidia-nvtx-cu11-11.7.91 pyparsing-3.0.9 sympy-1.11.1 torch-2.0.0 torchvision-0.15.1 triton-2.0.0 typing-extensions-4.5.0 wheel-0.40.0

# %%
# !pip install tensorboard
# Out:
# Collecting tensorboard
#   Downloading tensorboard-2.12.0-py3-none-any.whl (5.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.6/5.6 MB 64.5 MB/s eta 0:00:0000:0100:01
# Collecting protobuf>=3.19.6
#   Downloading protobuf-4.22.1-cp37-abi3-manylinux2014_x86_64.whl (302 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 302.4/302.4 kB 50.3 MB/s eta 0:00:00
# Collecting tensorboard-plugin-wit>=1.6.0
#   Downloading tensorboard_plugin_wit-1.8.1-py3-none-any.whl (781 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 781.3/781.3 kB 97.9 MB/s eta 0:00:00
# Collecting google-auth-oauthlib<0.5,>=0.4.1
#   Downloading google_auth_oauthlib-0.4.6-py2.py3-none-any.whl (18 kB)
# Requirement already satisfied: setuptools>=41.0.0 in ./venv/lib/python3.9/site-packages (from tensorboard) (59.6.0)
# Requirement already satisfied: requests<3,>=2.21.0 in ./venv/lib/python3.9/site-packages (from tensorboard) (2.28.2)
# Collecting google-auth<3,>=1.6.3
#   Downloading google_auth-2.16.3-py2.py3-none-any.whl (177 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 177.5/177.5 kB 41.2 MB/s eta 0:00:00
# Requirement already satisfied: wheel>=0.26 in ./venv/lib/python3.9/site-packages (from tensorboard) (0.40.0)
# Collecting absl-py>=0.4
#   Downloading absl_py-1.4.0-py3-none-any.whl (126 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 126.5/126.5 kB 32.9 MB/s eta 0:00:00
# Collecting werkzeug>=1.0.1
#   Downloading Werkzeug-2.2.3-py3-none-any.whl (233 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 233.6/233.6 kB 51.3 MB/s eta 0:00:00
# Collecting tensorboard-data-server<0.8.0,>=0.7.0
#   Downloading tensorboard_data_server-0.7.0-py3-none-manylinux2014_x86_64.whl (6.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 6.6/6.6 MB 125.7 MB/s eta 0:00:0000:01
# Requirement already satisfied: numpy>=1.12.0 in ./venv/lib/python3.9/site-packages (from tensorboard) (1.24.2)
# Collecting grpcio>=1.48.2
#   Downloading grpcio-1.51.3-cp39-cp39-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.8/4.8 MB 134.2 MB/s eta 0:00:0000:01
# Collecting markdown>=2.6.8
#   Downloading Markdown-3.4.3-py3-none-any.whl (93 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 93.9/93.9 kB 28.4 MB/s eta 0:00:00
# Collecting cachetools<6.0,>=2.0.0
#   Downloading cachetools-5.3.0-py3-none-any.whl (9.3 kB)
# Collecting rsa<5,>=3.1.4
#   Downloading rsa-4.9-py3-none-any.whl (34 kB)
# Requirement already satisfied: six>=1.9.0 in ./venv/lib/python3.9/site-packages (from google-auth<3,>=1.6.3->tensorboard) (1.16.0)
# Collecting pyasn1-modules>=0.2.1
#   Downloading pyasn1_modules-0.2.8-py2.py3-none-any.whl (155 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 155.3/155.3 kB 39.2 MB/s eta 0:00:00
# Collecting requests-oauthlib>=0.7.0
#   Downloading requests_oauthlib-1.3.1-py2.py3-none-any.whl (23 kB)
# Requirement already satisfied: importlib-metadata>=4.4 in ./venv/lib/python3.9/site-packages (from markdown>=2.6.8->tensorboard) (6.1.0)
# Requirement already satisfied: idna<4,>=2.5 in ./venv/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorboard) (3.4)
# Requirement already satisfied: certifi>=2017.4.17 in ./venv/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorboard) (2022.12.7)
# Requirement already satisfied: charset-normalizer<4,>=2 in ./venv/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorboard) (3.1.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in ./venv/lib/python3.9/site-packages (from requests<3,>=2.21.0->tensorboard) (1.26.15)
# Requirement already satisfied: MarkupSafe>=2.1.1 in ./venv/lib/python3.9/site-packages (from werkzeug>=1.0.1->tensorboard) (2.1.2)
# Requirement already satisfied: zipp>=0.5 in ./venv/lib/python3.9/site-packages (from importlib-metadata>=4.4->markdown>=2.6.8->tensorboard) (3.15.0)
# Collecting pyasn1<0.5.0,>=0.4.6
#   Downloading pyasn1-0.4.8-py2.py3-none-any.whl (77 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 77.1/77.1 kB 25.6 MB/s eta 0:00:00
# Collecting oauthlib>=3.0.0
#   Downloading oauthlib-3.2.2-py3-none-any.whl (151 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 151.7/151.7 kB 42.1 MB/s eta 0:00:00
# Installing collected packages: tensorboard-plugin-wit, pyasn1, werkzeug, tensorboard-data-server, rsa, pyasn1-modules, protobuf, oauthlib, grpcio, cachetools, absl-py, requests-oauthlib, markdown, google-auth, google-auth-oauthlib, tensorboard
# Successfully installed absl-py-1.4.0 cachetools-5.3.0 google-auth-2.16.3 google-auth-oauthlib-0.4.6 grpcio-1.51.3 markdown-3.4.3 oauthlib-3.2.2 protobuf-4.22.1 pyasn1-0.4.8 pyasn1-modules-0.2.8 requests-oauthlib-1.3.1 rsa-4.9 tensorboard-2.12.0 tensorboard-data-server-0.7.0 tensorboard-plugin-wit-1.8.1 werkzeug-2.2.3

# %%
# !pip install opencv-python
# Out:
# Requirement already satisfied: opencv-python in ./venv/lib/python3.9/site-packages (4.7.0.72)
# Requirement already satisfied: numpy>=1.17.3 in ./venv/lib/python3.9/site-packages (from opencv-python) (1.24.2)

# %%
# !sudo yum install libglvnd-glx -y
# Out:
# Last metadata expiration check: 1 day, 5:57:07 ago on Sat Mar 25 20:57:05 2023.
# Dependencies resolved.
# ================================================================================
#  Package             Arch      Version                     Repository      Size
# ================================================================================
# Installing:
#  libglvnd-glx        x86_64    1:1.3.4-1.amzn2023.0.2      amazonlinux    141 k
# Installing dependencies:
#  libX11              x86_64    1.7.2-3.amzn2023.0.2        amazonlinux    657 k
#  libX11-common       noarch    1.7.2-3.amzn2023.0.2        amazonlinux    152 k
#  libX11-xcb          x86_64    1.7.2-3.amzn2023.0.2        amazonlinux     12 k
#  libXau              x86_64    1.0.9-6.amzn2023.0.2        amazonlinux     31 k
#  libXext             x86_64    1.3.4-6.amzn2023.0.2        amazonlinux     41 k
#  libXfixes           x86_64    6.0.0-1.amzn2023.0.2        amazonlinux     20 k
#  libXxf86vm          x86_64    1.1.4-16.amzn2023.0.2       amazonlinux     19 k
#  libdrm              x86_64    2.4.110-1.amzn2023.0.2      amazonlinux    164 k
#  libglvnd            x86_64    1:1.3.4-1.amzn2023.0.2      amazonlinux    138 k
#  libpciaccess        x86_64    0.16-4.amzn2023.0.2         amazonlinux     28 k
#  libxcb              x86_64    1.13.1-7.amzn2023.0.2       amazonlinux    230 k
#  libxshmfence        x86_64    1.3-8.amzn2023.0.2          amazonlinux     13 k
#  llvm-libs           x86_64    15.0.6-2.amzn2023.0.2       amazonlinux     25 M
#  mesa-filesystem     x86_64    22.3.3-1140.amzn2023.0.3    amazonlinux     19 k
#  mesa-libGL          x86_64    22.3.3-1140.amzn2023.0.3    amazonlinux    178 k
#  mesa-libglapi       x86_64    22.3.3-1140.amzn2023.0.3    amazonlinux     55 k
# Installing weak dependencies:
#  mesa-dri-drivers    x86_64    22.3.3-1140.amzn2023.0.3    amazonlinux     18 M
#  mesa-va-drivers     x86_64    22.3.3-1140.amzn2023.0.3    amazonlinux    3.6 M
#
# Transaction Summary
# ================================================================================
# Install  19 Packages
#
# Total download size: 49 M
# Installed size: 212 M
# Downloading Packages:
# (1/19): libX11-1.7.2-3.amzn2023.0.2.x86_64.rpm  4.6 MB/s | 657 kB     00:00
# (2/19): libxcb-1.13.1-7.amzn2023.0.2.x86_64.rpm 1.6 MB/s | 230 kB     00:00
# (3/19): mesa-libglapi-22.3.3-1140.amzn2023.0.3. 1.2 MB/s |  55 kB     00:00
# (4/19): libglvnd-glx-1.3.4-1.amzn2023.0.2.x86_6 1.9 MB/s | 141 kB     00:00
# (5/19): libXfixes-6.0.0-1.amzn2023.0.2.x86_64.r 488 kB/s |  20 kB     00:00
# (6/19): mesa-dri-drivers-22.3.3-1140.amzn2023.0  52 MB/s |  18 MB     00:00
# (7/19): mesa-libGL-22.3.3-1140.amzn2023.0.3.x86 1.4 MB/s | 178 kB     00:00
# (8/19): libdrm-2.4.110-1.amzn2023.0.2.x86_64.rp 1.3 MB/s | 164 kB     00:00
# (9/19): libXxf86vm-1.1.4-16.amzn2023.0.2.x86_64 937 kB/s |  19 kB     00:00
# (10/19): libXext-1.3.4-6.amzn2023.0.2.x86_64.rp 1.1 MB/s |  41 kB     00:00
# (11/19): mesa-filesystem-22.3.3-1140.amzn2023.0 461 kB/s |  19 kB     00:00
# (12/19): libxshmfence-1.3-8.amzn2023.0.2.x86_64 317 kB/s |  13 kB     00:00
# (13/19): libX11-xcb-1.7.2-3.amzn2023.0.2.x86_64 328 kB/s |  12 kB     00:00
# (14/19): libglvnd-1.3.4-1.amzn2023.0.2.x86_64.r 2.2 MB/s | 138 kB     00:00
# (15/19): libXau-1.0.9-6.amzn2023.0.2.x86_64.rpm 930 kB/s |  31 kB     00:00
# (16/19): libpciaccess-0.16-4.amzn2023.0.2.x86_6 1.0 MB/s |  28 kB     00:00
# (17/19): libX11-common-1.7.2-3.amzn2023.0.2.noa 2.0 MB/s | 152 kB     00:00
# (18/19): llvm-libs-15.0.6-2.amzn2023.0.2.x86_64  65 MB/s |  25 MB     00:00
# (19/19): mesa-va-drivers-22.3.3-1140.amzn2023.0  11 MB/s | 3.6 MB     00:00
# --------------------------------------------------------------------------------
# Total                                            57 MB/s |  49 MB     00:00
# Running transaction check
# Transaction check succeeded.
# Running transaction test
# Transaction test succeeded.
# Running transaction
#   Preparing        :                                                        1/1
#   Installing       : libX11-xcb-1.7.2-3.amzn2023.0.2.x86_64                1/19
#   Installing       : llvm-libs-15.0.6-2.amzn2023.0.2.x86_64                2/19
#   Installing       : libxshmfence-1.3-8.amzn2023.0.2.x86_64                3/19
#   Installing       : mesa-filesystem-22.3.3-1140.amzn2023.0.3.x86_64       4/19
#   Installing       : mesa-libglapi-22.3.3-1140.amzn2023.0.3.x86_64         5/19
#   Installing       : libX11-common-1.7.2-3.amzn2023.0.2.noarch             6/19
#   Installing       : libpciaccess-0.16-4.amzn2023.0.2.x86_64               7/19
#   Installing       : libdrm-2.4.110-1.amzn2023.0.2.x86_64                  8/19
#   Installing       : libXau-1.0.9-6.amzn2023.0.2.x86_64                    9/19
#   Installing       : libxcb-1.13.1-7.amzn2023.0.2.x86_64                  10/19
#   Installing       : libX11-1.7.2-3.amzn2023.0.2.x86_64                   11/19
#   Installing       : libXext-1.3.4-6.amzn2023.0.2.x86_64                  12/19
#   Installing       : libXxf86vm-1.1.4-16.amzn2023.0.2.x86_64              13/19
#   Installing       : libXfixes-6.0.0-1.amzn2023.0.2.x86_64                14/19
#   Installing       : mesa-va-drivers-22.3.3-1140.amzn2023.0.3.x86_64      15/19
#   Installing       : mesa-dri-drivers-22.3.3-1140.amzn2023.0.3.x86_64     16/19
#   Installing       : libglvnd-1:1.3.4-1.amzn2023.0.2.x86_64               17/19
#   Installing       : libglvnd-glx-1:1.3.4-1.amzn2023.0.2.x86_64           18/19
#   Installing       : mesa-libGL-22.3.3-1140.amzn2023.0.3.x86_64           19/19
#   Running scriptlet: mesa-libGL-22.3.3-1140.amzn2023.0.3.x86_64           19/19
#   Verifying        : libxcb-1.13.1-7.amzn2023.0.2.x86_64                   1/19
#   Verifying        : mesa-dri-drivers-22.3.3-1140.amzn2023.0.3.x86_64      2/19
#   Verifying        : libX11-1.7.2-3.amzn2023.0.2.x86_64                    3/19
#   Verifying        : mesa-libglapi-22.3.3-1140.amzn2023.0.3.x86_64         4/19
#   Verifying        : libglvnd-glx-1:1.3.4-1.amzn2023.0.2.x86_64            5/19
#   Verifying        : libXfixes-6.0.0-1.amzn2023.0.2.x86_64                 6/19
#   Verifying        : mesa-libGL-22.3.3-1140.amzn2023.0.3.x86_64            7/19
#   Verifying        : libdrm-2.4.110-1.amzn2023.0.2.x86_64                  8/19
#   Verifying        : libXxf86vm-1.1.4-16.amzn2023.0.2.x86_64               9/19
#   Verifying        : mesa-filesystem-22.3.3-1140.amzn2023.0.3.x86_64      10/19
#   Verifying        : libXext-1.3.4-6.amzn2023.0.2.x86_64                  11/19
#   Verifying        : libxshmfence-1.3-8.amzn2023.0.2.x86_64               12/19
#   Verifying        : libglvnd-1:1.3.4-1.amzn2023.0.2.x86_64               13/19
#   Verifying        : llvm-libs-15.0.6-2.amzn2023.0.2.x86_64               14/19
#   Verifying        : libX11-xcb-1.7.2-3.amzn2023.0.2.x86_64               15/19
#   Verifying        : libXau-1.0.9-6.amzn2023.0.2.x86_64                   16/19
#   Verifying        : libpciaccess-0.16-4.amzn2023.0.2.x86_64              17/19
#   Verifying        : mesa-va-drivers-22.3.3-1140.amzn2023.0.3.x86_64      18/19
#   Verifying        : libX11-common-1.7.2-3.amzn2023.0.2.noarch            19/19
# ================================================================================
# WARNING:
#   A newer release of "Amazon Linux" is available.
#
#   Available Versions:
#
#   Version 2023.0.20230322:
#     Run the following command to upgrade to 2023.0.20230322:
#
#       dnf upgrade --releasever=2023.0.20230322
#
#     Release notes:
#      https://docs.aws.amazon.com/linux/al2023/release-notes/relnotes.html
#
# ================================================================================
#
# Installed:
#   libX11-1.7.2-3.amzn2023.0.2.x86_64
#   libX11-common-1.7.2-3.amzn2023.0.2.noarch
#   libX11-xcb-1.7.2-3.amzn2023.0.2.x86_64
#   libXau-1.0.9-6.amzn2023.0.2.x86_64
#   libXext-1.3.4-6.amzn2023.0.2.x86_64
#   libXfixes-6.0.0-1.amzn2023.0.2.x86_64
#   libXxf86vm-1.1.4-16.amzn2023.0.2.x86_64
#   libdrm-2.4.110-1.amzn2023.0.2.x86_64
#   libglvnd-1:1.3.4-1.amzn2023.0.2.x86_64
#   libglvnd-glx-1:1.3.4-1.amzn2023.0.2.x86_64
#   libpciaccess-0.16-4.amzn2023.0.2.x86_64
#   libxcb-1.13.1-7.amzn2023.0.2.x86_64
#   libxshmfence-1.3-8.amzn2023.0.2.x86_64
#   llvm-libs-15.0.6-2.amzn2023.0.2.x86_64
#   mesa-dri-drivers-22.3.3-1140.amzn2023.0.3.x86_64
#   mesa-filesystem-22.3.3-1140.amzn2023.0.3.x86_64
#   mesa-libGL-22.3.3-1140.amzn2023.0.3.x86_64
#   mesa-libglapi-22.3.3-1140.amzn2023.0.3.x86_64
#   mesa-va-drivers-22.3.3-1140.amzn2023.0.3.x86_64
#
# Complete!

# %%
# !pip install seaborn
# Out:
# Collecting seaborn
#   Downloading seaborn-0.12.2-py3-none-any.whl (293 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 293.3/293.3 kB 8.0 MB/s eta 0:00:0000:01
# Requirement already satisfied: matplotlib!=3.6.1,>=3.1 in ./venv/lib/python3.9/site-packages (from seaborn) (3.7.1)
# Requirement already satisfied: numpy!=1.24.0,>=1.17 in ./venv/lib/python3.9/site-packages (from seaborn) (1.24.2)
# Requirement already satisfied: pandas>=0.25 in ./venv/lib/python3.9/site-packages (from seaborn) (1.5.3)
# Requirement already satisfied: kiwisolver>=1.0.1 in ./venv/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.4.4)
# Requirement already satisfied: importlib-resources>=3.2.0 in ./venv/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (5.12.0)
# Requirement already satisfied: packaging>=20.0 in ./venv/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (23.0)
# Requirement already satisfied: python-dateutil>=2.7 in ./venv/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (2.8.2)
# Requirement already satisfied: fonttools>=4.22.0 in ./venv/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (4.39.2)
# Requirement already satisfied: cycler>=0.10 in ./venv/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (0.11.0)
# Requirement already satisfied: pillow>=6.2.0 in ./venv/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (9.4.0)
# Requirement already satisfied: pyparsing>=2.3.1 in ./venv/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (3.0.9)
# Requirement already satisfied: contourpy>=1.0.1 in ./venv/lib/python3.9/site-packages (from matplotlib!=3.6.1,>=3.1->seaborn) (1.0.7)
# Requirement already satisfied: pytz>=2020.1 in ./venv/lib/python3.9/site-packages (from pandas>=0.25->seaborn) (2023.2)
# Requirement already satisfied: zipp>=3.1.0 in ./venv/lib/python3.9/site-packages (from importlib-resources>=3.2.0->matplotlib!=3.6.1,>=3.1->seaborn) (3.15.0)
# Requirement already satisfied: six>=1.5 in ./venv/lib/python3.9/site-packages (from python-dateutil>=2.7->matplotlib!=3.6.1,>=3.1->seaborn) (1.16.0)
# Installing collected packages: seaborn
# Successfully installed seaborn-0.12.2
